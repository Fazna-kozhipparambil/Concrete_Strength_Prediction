# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\maz\Desktop\fazna study\project_3_concrete_strength\concrete.csv")

# %%
df.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
df.shape
# Out:
# (1030, 9)

# %%
df1=df.iloc[:103]

# %%
df1
# Out:
#      cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0     141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1     168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2     250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3     266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4     154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ..      ...    ...    ...    ...           ...        ...      ...  ...
# 98    252.0   97.0   76.0  194.0           8.0      835.0    821.0   28
# 99    237.5  237.5    0.0  228.0           0.0      932.0    594.0  180
# 100   149.5  236.0    0.0  175.8          12.6      846.8    892.7   28
# 101   540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 102   313.0    0.0  113.0  178.0           8.0     1002.0    689.0   28
#
#      strength
# 0       29.89
# 1       23.51
# 2       29.22
# 3       45.85
# 4       18.29
# ...

# %%
df2=df.iloc[103:]
df2
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 103    380.0    0.0    0.0  228.0           0.0      932.0    670.0  180
# 104    251.4    0.0  118.3  192.9           5.8     1043.6    754.3    3
# 105    436.0    0.0    0.0  218.0           0.0      838.4    719.7   28
# 106    155.0    0.0  143.0  193.0           9.0      877.0    868.0   28
# 107    281.0    0.0    0.0  186.0           0.0     1104.0    774.0    7
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 103      53.10
# 104      11.98
# 105      23.85
# 106       9.74
# ...

# %%
x_train=df2.drop("strength",axis=1)
x_train
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age
# 103    380.0    0.0    0.0  228.0           0.0      932.0    670.0  180
# 104    251.4    0.0  118.3  192.9           5.8     1043.6    754.3    3
# 105    436.0    0.0    0.0  218.0           0.0      838.4    719.7   28
# 106    155.0    0.0  143.0  193.0           9.0      877.0    868.0   28
# 107    281.0    0.0    0.0  186.0           0.0     1104.0    774.0    7
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
# [927 rows x 8 columns]

# %%
x_test=df1.drop("strength",axis=1)
x_test
# Out:
#      cement   slag    ash  water  superplastic  coarseagg  fineagg  age
# 0     141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1     168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2     250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3     266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4     154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ..      ...    ...    ...    ...           ...        ...      ...  ...
# 98    252.0   97.0   76.0  194.0           8.0      835.0    821.0   28
# 99    237.5  237.5    0.0  228.0           0.0      932.0    594.0  180
# 100   149.5  236.0    0.0  175.8          12.6      846.8    892.7   28
# 101   540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 102   313.0    0.0  113.0  178.0           8.0     1002.0    689.0   28
#
# [103 rows x 8 columns]

# %%
y_test=df1.strength
y_test
# Out:
# 0      29.89
# 1      23.51
# 2      29.22
# 3      45.85
# 4      18.29
#        ...
# 98     33.40
# 99     36.25
# 100    32.96
# 101    61.89
# 102    36.80
# Name: strength, Length: 103, dtype: float64

# %%
y_train=df2.strength
y_train
# Out:
# 103     53.10
# 104     11.98
# 105     23.85
# 106      9.74
# 107     14.50
#         ...
# 1025    13.29
# 1026    41.30
# 1027    44.28
# 1028    55.06
# 1029    52.61
# Name: strength, Length: 927, dtype: float64

# %%
df.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %% [markdown]
# # finding missing values

# %%
df.isna().sum()
# Out:
# cement          0
# slag            0
# ash             0
# water           0
# superplastic    0
# coarseagg       0
# fineagg         0
# age             0
# strength        0
# dtype: int64

# %% [markdown]
# # plotting

# %%
pd.plotting.scatter_matrix(df[['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
       'fineagg', 'age', 'strength']], alpha=0.2,figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='cement', ylabel='cement'>,
#         <AxesSubplot:xlabel='slag', ylabel='cement'>,
#         <AxesSubplot:xlabel='ash', ylabel='cement'>,
#         <AxesSubplot:xlabel='water', ylabel='cement'>,
#         <AxesSubplot:xlabel='superplastic', ylabel='cement'>,
#         <AxesSubplot:xlabel='coarseagg', ylabel='cement'>,
#         <AxesSubplot:xlabel='fineagg', ylabel='cement'>,
#         <AxesSubplot:xlabel='age', ylabel='cement'>,
#         <AxesSubplot:xlabel='strength', ylabel='cement'>],
#        [<AxesSubplot:xlabel='cement', ylabel='slag'>,
#         <AxesSubplot:xlabel='slag', ylabel='slag'>,
#         <AxesSubplot:xlabel='ash', ylabel='slag'>,
#         <AxesSubplot:xlabel='water', ylabel='slag'>,
#         <AxesSubplot:xlabel='superplastic', ylabel='slag'>,
#         <AxesSubplot:xlabel='coarseagg', ylabel='slag'>,
#         <AxesSubplot:xlabel='fineagg', ylabel='slag'>,
#         <AxesSubplot:xlabel='age', ylabel='slag'>,
# ...

# %%
import seaborn as sns
for i in df.columns:
    print(i)
    sns.boxplot(x=df[i])
    plt.xlabel(i)
    plt.ylabel("strength")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# cement
# slag
# ash
# water
# superplastic
# coarseagg
# fineagg
# age
# strength

# %% [markdown]
# # concrete strength prediction

# %%
#linear regression
import numpy as np
from sklearn.linear_model import LinearRegression
y=df.strength
X=df[['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
       'fineagg', 'age']]
reg = LinearRegression().fit(X, y)

# %%
reg.coef_
# Out:
# array([ 0.11980433,  0.10386581,  0.08793432, -0.14991842,  0.2922246 ,
#         0.01808621,  0.02019035,  0.11422207])

# %%
reg.intercept_
# Out:
# -23.331213584903132

# %%
y_pred=reg.predict(X)

# %%
y_pred
# Out:
# array([20.99517133, 28.86329915, 26.44055536, ..., 39.89433852,
#        48.63121587, 48.9504719 ])

# %%
plt.scatter(y,y_pred)
plt.plot(y,y,color="red")
plt.xlabel("actual strength")
plt.ylabel("strength predicted")
# Out:
# Text(0, 0.5, 'strength predicted')

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y,y_pred)
# Out:
# 107.19723607486019

# %%
rom sklearn.metrics import r2_score
r2_score(y,y_pred)f
# Out:
# 0.6155198704142721

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y,y_pred)
# Out:
# 0.31306332747562193

# %% [markdown]
# # lasso

# %%
from sklearn import linear_model
las = linear_model.Lasso(alpha=10)
y=df.strength
X=df.drop(['strength'],axis=1)
las.fit(X,y)
print(las.coef_)
print(las.intercept_)
# Out:
# [ 0.11027374  0.09109642  0.07846055 -0.22035186  0.          0.
#   0.00521728  0.10900354]
# 24.824599806024413

# %%
y_predict1=las.predict(X)

# %%
y_predict1
# Out:
# array([21.83435376, 27.84510258, 26.15299646, ..., 40.44177949,
#        48.68619548, 50.21276943])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y,y_predict1)
# Out:
# 108.71385098565241

# %%
from sklearn.metrics import r2_score
r2_score(y,y_predict1)
# Out:
# 0.6100802870930582

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y,y_predict1)
# Out:
# 0.3212477336767781

# %%
plt.scatter(y,y_predict1,color="green",s=5)
plt.plot(y,y,color="blue")
plt.xlabel("Strength actual")
plt.ylabel("Strength predicted")
# Out:
# Text(0, 0.5, 'Strength predicted')

# %% [markdown]
# # ridge

# %%
from sklearn.linear_model import Ridge
import numpy as np
y = df.strength
X=df[['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
       'fineagg', 'age']]
rid= Ridge(alpha=5.0)
rid.fit(X, y)
rid.score(X,y)
# Out:
# 0.615519869940483

# %%
y_predict2=rid.predict(X)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y,y_predict1)
# Out:
# 108.71385098565241

# %%
from sklearn.metrics import r2_score
r2_score(y,y_predict2)
# Out:
# 0.6155198703953082

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y,y_predict2)
# Out:
# 0.3130634981905724

# %% [markdown]
# PLOTTING

# %%
plt.scatter(y,y_predict2,color="green",s=5)
plt.plot(y,y,color="blue")
plt.xlabel("Strength actual")
plt.ylabel("Strength predicted")
# Out:
# Text(0, 0.5, 'Strength predicted')

# %%
df.corr()
# Out:
#                 cement      slag       ash     water  superplastic  coarseagg  \
# cement        1.000000 -0.275216 -0.397467 -0.081587      0.092386  -0.109349
# slag         -0.275216  1.000000 -0.323580  0.107252      0.043270  -0.283999
# ash          -0.397467 -0.323580  1.000000 -0.256984      0.377503  -0.009961
# water        -0.081587  0.107252 -0.256984  1.000000     -0.657533  -0.182294
# superplastic  0.092386  0.043270  0.377503 -0.657533      1.000000  -0.265999
# coarseagg    -0.109349 -0.283999 -0.009961 -0.182294     -0.265999   1.000000
# fineagg      -0.222718 -0.281603  0.079108 -0.450661      0.222691  -0.178481
# age           0.081946 -0.044246 -0.154371  0.277618     -0.192700  -0.003016
# strength      0.497832  0.134829 -0.105755 -0.289633      0.366079  -0.164935
#
#                fineagg       age  strength
# cement       -0.222718  0.081946  0.497832
# slag         -0.281603 -0.044246  0.134829
# ash           0.079108 -0.154371 -0.105755
# ...

# %% [markdown]
# # prediction after test train data set

# %% [markdown]
# # linear regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train, y_train)
y_pred=reg.predict(x_test)
mean_squared_error(y_test,y_pred)
# Out:
# 100.79267354529063

# %%
reg = LinearRegression().fit(x_train, y_train)
y_pred=reg.predict(x_test)
print("mean_squared_error",mean_squared_error(y_test,y_pred))
print(mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mean_squared_error 100.79267354529063
# 0.27953792667918914

# %%
las = linear_model.Lasso(alpha=50)
las.fit(x_train ,y_train)
y_pred=las.predict(x_test)
print("mean squared error is",mean squared_error(y_test,y_pred))
mean_absolute_percentage_error(y_test,y_pred)
# Out:
#   File "C:\Users\maz\AppData\Local\Temp/ipykernel_15648/1893184314.py", line 4
#     print("mean squared error is",mean squared_error(y_test,y_pred))
#                                        ^
# SyntaxError: invalid syntax
